# %% [markdown]
# ##Demo 1: Using Web Maps to Find the Location of Rental Bike

# %% [markdown]
# Here we will find out all the location of rental bikes in Dublin, Ireland.For this problem statement,we use the dataset of Dublin to find the location of all the rental bikes based on their latitude and longitude.

# %%
#import all the necessary libraries
import pandas as pd
import folium

# %%
#read the dataset and display the first five rows
df = pd.read_csv("dublin.csv")
df.head()
# Out:
#    Number                  Name               Address   Latitude  Longitude
# 0      42      SMITHFIELD NORTH      Smithfield North  53.349562  -6.278198
# 1      30  PARNELL SQUARE NORTH  Parnell Square North  53.353462  -6.265305
# 2      54        CLONMEL STREET        Clonmel Street  53.336021  -6.262980
# 3     108         AVONDALE ROAD         Avondale Road  53.359405  -6.276142
# 4      56    MOUNT STREET LOWER    Mount Street Lower  53.337960  -6.241530

# %%
#for the sake of convenience we will be using three features - latitude, longitude, and name
df1 = df[["Latitude", "Longitude", "Name"]]

# %%
#The latitude and longitude are passed to the location parameter of Map.
map = folium.Map(location=[df1.Latitude.mean(), df1.Longitude.mean()], zoom_start=14, control_scale=True)

# %%
#The markers are pointed on the location where rental bikes can be found.The resulting map is stored in a html file.
m=folium.Map()
for index, location in df1.iterrows():
    marker = folium.Marker([location["Latitude"], location["Longitude"]], popup=location["Name"],icon=folium.Icon(color="green"))
    marker.add_to(m)
m.save("map1.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fd5c24fc793778f488abe72d4f7295a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fd5c24fc793778f488abe72d4f7295a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8fd5c24fc793778f488abe72d4f7295a = L.map(
#                 &quot;map_8fd5c24fc793778f488abe72d4f7295a&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2452d73166a803cce7ab4e8436b19bdb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8fd5c24fc793778f488abe72d4f7295a);
#
#
#             var marker_e931d3554ae3c87b485802e7b3dfb482 = L.marker(
#                 [53.349562, -6.278198],
#                 {}
#             ).addTo(map_8fd5c24fc793778f488abe72d4f7295a);
#
#
#             var icon_3c58fcf3f079c39c0255b99bfcf431e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e931d3554ae3c87b485802e7b3dfb482.setIcon(icon_3c58fcf3f079c39c0255b99bfcf431e3);
#
#
#         var popup_b00121b62438f802369e6af8d4c157ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1b17b136010a438a6fcde9fd2c27d882 = $(`&lt;div id=&quot;html_1b17b136010a438a6fcde9fd2c27d882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SMITHFIELD NORTH&lt;/div&gt;`)[0];
#             popup_b00121b62438f802369e6af8d4c157ef.setContent(html_1b17b136010a438a6fcde9fd2c27d882);
#
#
#         marker_e931d3554ae3c87b485802e7b3dfb482.bindPopup(popup_b00121b62438f802369e6af8d4c157ef)
#         ;
#
#
#
#
#             var marker_7f3b31f5321f91bd2a2fe955625fa40c = L.marker(
#                 [53.353462, -6.265305],
#                 {}
#             ).addTo(map_8fd5c24fc793778f488abe72d4f7295a);
#
#
#             var icon_d7034dfbfa400e275fdc8a7505f6c8fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f3b31f5321f91bd2a2fe955625fa40c.setIcon(icon_d7034dfbfa400e275fdc8a7505f6c8fa);
#
#
#         var popup_7744a146a270d1f15828946f8de336b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9310cff4686f8452d25f97a7f328b93d = $(`&lt;div id=&quot;html_9310cff4686f8452d25f97a7f328b93d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PARNELL SQUARE NORTH&lt;/div&gt;`)[0];
#             popup_7744a146a270d1f15828946f8de336b9.setContent(html_9310cff4686f8452d25f97a7f328b93d);
#
#
#         marker_7f3b31f5321f91bd2a2fe955625fa40c.bindPopup(popup_7744a146a270d1f15828946f8de336b9)
#         ;
#
#
#
#
#             var marker_a72cc6417c3d45db43df7de0ea3167f2 = L.marker(
#                 [53.336021, -6.26298],
#                 {}
#             ).addTo(map_8fd5c24fc793778f488abe72d4f7295a);
#
#
#             var icon_6f16306bbace824541b1e63acfe41a45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a72cc6417c3d45db43df7de0ea3167f2.setIcon(icon_6f16306bbace824541b1e63acfe41a45);
#
#
#         var popup_762683f5780a21e767c50dfc9413591c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1d51cd17aebb70bef74a3724fa7ede9f = $(`&lt;div id=&quot;html_1d51cd17aebb70bef74a3724fa7ede9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CLONMEL STREET&lt;/div&gt;`)[0];
#             popup_762683f5780a21e767c50dfc9413591c.setContent(html_1d51cd17aebb70bef74a3724fa7ede9f);
#
#
#         marker_a72cc6417c3d45db43df7de0ea3167f2.bindPopup(popup_762683f5780a21e767c50dfc9413591c)
#         ;
#
#
#
#
#             var marker_1490e4a34b7d2b119e9cadb98dd5657c = L.marker(
#                 [53.359405, -6.276142],
#                 {}
#             ).addTo(map_8fd5c24fc793778f488abe72d4f7295a);
#
#
#             var icon_528bd8f3a42e61a24936c54a06616932 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1490e4a34b7d2b119e9cadb98dd5657c.setIcon(icon_528bd8f3a42e61a24936

# %% [markdown]
# Conclusion: When we download and open the map1.html file we can see all the locations in Dublin where rental locations of bike can be found.
