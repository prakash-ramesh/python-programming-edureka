# %% [markdown]
# ```
# 1. You are given a dataset, which is present in the LMS, containing the number of hurricanes occurring in the United States along the coast of the Atlantic.
#
# Load the data from the dataset into your program and plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df_hurr = pd.read_csv("Hurricanes.csv")
df_hurr.head()
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10
# 3  1917           2
# 4  1918           4

# %%
plt.figure(figsize=(50,8))
plt.xlabel("Year")
plt.ylabel("No. of Hurricanes")
plt.bar(df_hurr['Year'], df_hurr['Hurricanes'])
plt.savefig("Hurricanes.jpg")
plt.show()

# %% [markdown]
# ```
# 2. The dataset given, records data of city temperatures over the years 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow
# ```

# %%
df_temp = pd.read_csv("CityTemps.csv")
df_temp.head()
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0
# 3  2014      4     7.0       15.8           15.7
# 4  2014      5    16.0       13.9           17.5

# %%
plt.hist(df_temp['Moscow'])
# Out:
# (array([1., 2., 4., 3., 3., 1., 0., 3., 4., 3.]),
#  array([-8.6 , -5.63, -2.66,  0.31,  3.28,  6.25,  9.22, 12.19, 15.16,
#         18.13, 21.1 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_temp['San Francisco'])
# Out:
# (array([1., 1., 3., 1., 4., 3., 1., 2., 2., 6.]),
#  array([10.3 , 11.31, 12.32, 13.33, 14.34, 15.35, 16.36, 17.37, 18.38,
#         19.39, 20.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ```
# 3. Plot apiechartof the number of models released by every manufacturer, recorded in the dataprovided. Also mention the name of the manufacturerwith the largest releases
# ```

# %%
df_cars = pd.read_csv("Cars2015.csv")
df_cars.head()
# Out:
#          Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0   Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1     Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2         Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3  Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4      Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
#
#    HwyMPG  FuelCap  Length  Width  Wheelbase  Height  UTurn  Weight  Acc030  \
# 0      39      9.0     145     63         94      61     34    2345     4.4
# 1      37     11.4     172     67        101      57     37    2550     3.7
# 2      36     11.3     172     68        101      57     37    2575     3.5
# 3      44      9.2     149     66         97      59     32    2085     4.4
# 4      40     10.9     164     67        102      61     37    2470     4.0
#
#    Acc060  QtrMile  PageNum   Size
# ...

# %%
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return f"{round(pct, 2)} %"

make_lbl = list(set(df_cars['Make']))
model_cnt = []
for c in make_lbl:
    model_cnt.append(len(df_cars[df_cars.Make == c]))

plt.figure(figsize=(20,20))
plt.pie(model_cnt, labels=make_lbl, autopct=lambda pct: func(pct, model_cnt), explode=[c/100 if c == max(model_cnt) else 0 for c in model_cnt])
plt.savefig("Cars.jpg")

# %% [markdown]
# ```
# 4.
# Create csv file from the data below and readit in the pandas’s dataframe.
# Phase 1: Reading data
# Phase 2: Describe the dataDescribe the data on the unitprice.
# Phase 3: Filter the dataCreate  a new  dataframe  having  columns 'name','net_price','date'  and  group  all  the records according to name.
# Phase 4: Plotting graphPlot the graph after calculating total sales by each customer. Customer name should be the onthe  x-axisand  total  saleson  y-axis.
#
# Refer  to  sample-salesv2  to  answer  the following questions
# ```

# %%
df_sales = pd.read_csv("sample-salesv2.csv")
df_sales.head()
# Out:
#    account_number                           name item_code category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  net_price              date
# 0       44.48     578.24  27-09-2014 07:13
# 1       53.62    1018.78  29-07-2014 02:10
# 2       24.16     289.92  01-03-2014 10:51
# 3       82.68     413.40  17-11-2013 20:41
# 4       99.64    1793.52  03-01-2014 08:14

# %%
df_sales.describe()
# Out:
#        account_number     quantity   unit price   net_price
# count     1000.000000  1000.000000  1000.000000  1000.00000
# mean    535208.897000    10.328000    56.179630   579.84390
# std     277589.746014     5.687597    25.331939   435.30381
# min      93356.000000     1.000000    10.060000    10.38000
# 25%     299771.000000     5.750000    35.995000   232.60500
# 50%     563905.000000    10.000000    56.765000   471.72000
# 75%     750461.000000    15.000000    76.802500   878.13750
# max     995267.000000    20.000000    99.970000  1994.80000

# %%
df_s = df_sales[['name', 'net_price', 'date']]
df_s
# Out:
#                               name  net_price              date
# 0                      Carroll PLC     578.24  27-09-2014 07:13
# 1                Heidenreich-Bosco    1018.78  29-07-2014 02:10
# 2    Kerluke, Reilly and Bechtelar     289.92  01-03-2014 10:51
# 3                    Waters-Walker     413.40  17-11-2013 20:41
# 4                    Waelchi-Fahey    1793.52  03-01-2014 08:14
# ..                             ...        ...               ...
# 995      Kihn, McClure and Denesik     665.50  03-08-2014 10:39
# 996                      Kunze Inc     314.56  03-05-2014 21:18
# 997                  Waters-Walker    1182.35  14-06-2014 12:43
# 998                      Huel-Haag     883.98  26-07-2014 01:10
# 999              Heidenreich-Bosco    1047.62  27-06-2014 05:58
#
# [1000 rows x 3 columns]

# %%
grp = df_s.groupby('name')['net_price'].sum()

# %%
grp.plot.bar()
# Out:
# <Axes: xlabel='name'>

# %% [markdown]
# ```
# 5.Let the x-axisdata points and y-axisdata points are
# X = [1,2,3,4]
# y = [20, 21, 20.5, 20.8]
# 5.1: Draw a Simple plot
# 5.2: Configure the line and markers in a simple plot
# 5.3: configure the axes
# 5.4: Give the title of the graph andlabels of the x-axis and y-axis
# 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
# 5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100
# 5.7: Give a font size of 14
# 5.8: Draw a scatter graph of any 50 random values of the x and y-axis
# 5.9: Create a dataframe from the following data'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73], 'preTestScore': [4, 24, 31, 2, 3],'postTestScore': [25, 94, 57, 62, 70]Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age.
# 5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex
# ```

# %%
x = [1,2,3,4]
y = [20, 21, 20.5, 20.8]
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x, y, marker='o')

plt.title("Simple Plot", fontsize=14)
plt.figure(figsize=(4,5), dpi=100)

y_error = [0.12, 0.13, 0.2, 0.1]
plt.errorbar(x, y, y_error, marker='o', color='red')
plt.show()

# %%
scatter_x = np.random.randn(50)
scatter_y = np.random.randn(50)
plt.scatter(scatter_x,scatter_y)

# %%
data = {
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
}
df = pd.DataFrame(data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %%
plt.scatter(df['age'], df['preTestScore'])
plt.scatter(df['age'], df['postTestScore'], color='red')

# %%
plt.scatter(df['female'], df['preTestScore'])
plt.scatter(df['female'], df['postTestScore'], color='red')
